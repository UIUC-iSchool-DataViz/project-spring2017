# %% [markdown]
# # LIS 590 Term Project Component 1
#
# #### First Edit:  03/29/2017
# #### Last Edit: 04/05/2017

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import re
import time
from datetime import datetime
import ipywidgets

# %% [markdown]
# ## Read CUMTD data as pandas dataframes
#
# ---
# This part of codes deals with reading in original data.

# %%
### use command line to
### retrieve a list of all CUMTD txt files and 
### save the list as a text file named cumtd_allfiles.txt at the directory "~/work"

### if open this notebook on server, use this line:
#!ls ~/work/data-readonly/CUMTD/ > ~/work/cumtd_allfiles.txt

### if open this notebook locally, read from your local files, for example:
# !ls /Users/luol12/Desktop/590dataViz/project-spring2017/part1/google_transit > /Users/luol12/Desktop/590dataViz/project-spring2017/part1/cumtd_allfiles.txt

### retrieve file_allfiles.txt
file_list = pd.read_csv('cumtd_allfiles.txt', header = None)

### convert the pandas Series to an actual python list, the elements of which are strings
file_list = file_list[0].tolist()

### see what's in this file_list?
for file in file_list:
    print(file)
# Out:
# agency.txt
# calendar.txt
# calendar_dates.txt
# fare_attributes.txt
# fare_rules.txt
# routes.txt
# shapes.txt
# stop_times.txt
# stops.txt
# trips.txt

# %% [markdown]
# Now iteratively read in all the CUMTD txt files.

# %%
### save all the data in a dictionary named 'data', 
### each entry of the dict is a pandas DataFrame
data = {}
for file in file_list:
    data[file.replace(".txt","")] = pd.read_csv('/Users/luol12/Desktop/590dataViz/project-spring2017/part1/google_transit/' + file)

# %% [markdown]
# Look at what are columns in each dataset.

# %%
data.keys()
# Out:
# dict_keys(['stop_times', 'fare_rules', 'fare_attributes', 'agency', 'trips', 'calendar_dates', 'calendar', 'routes', 'shapes', 'stops'])

# %%
for key in data.keys():
    print("Keys in data['{0}']: \n{1}".format(key, data[key].keys()))
    print('-'*20)
# Out:
# Keys in data['stop_times']:
# Index(['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence',
#        'stop_headsign', 'pickup_type', 'drop_off_type'],
#       dtype='object')
# --------------------
# Keys in data['fare_rules']:
# Index(['fare_id', 'route_id', 'origin_id', 'destination_id', 'contains_id'], dtype='object')
# --------------------
# Keys in data['fare_attributes']:
# Index(['fare_id', 'price', 'currency_type', 'payment_method', 'transfers',
#        'transfer_duration'],
#       dtype='object')
# --------------------
# Keys in data['agency']:
# Index(['agency_id', 'agency_name', 'agency_url', 'agency_timezone',
#        'agency_lang', 'agency_phone'],
#       dtype='object')
# --------------------
# Keys in data['trips']:
# Index(['route_id', 'service_id', 'trip_id', 'trip_headsign', 'direction_id',
#        'block_id', 'shape_id'],
#       dtype='object')
# --------------------
# Keys in data['calendar_dates']:
# Index(['service_id', 'date', 'exception_type'], dtype='object')
# --------------------
# Keys in data['calendar']:
# Index(['service_id', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday',
#        'saturday', 'sunday', 'start_date', 'end_date'],
#       dtype='object')
# --------------------
# Keys in data['routes']:
# Index(['route_id', 'agency_id', 'route_short_name', 'route_long_name',
#        'route_desc', 'route_type', 'route_url', 'route_color',
#        'route_text_color'],
#       dtype='object')
# --------------------
# Keys in data['shapes']:
# Index(['shape_id', 'shape_pt_lat', 'shape_pt_lon', 'shape_pt_sequence',
#        'shape_dist_traveled'],
#       dtype='object')
# --------------------
# Keys in data['stops']:
# Index(['stop_id', 'stop_code', 'stop_name', 'stop_desc', 'stop_lat',
#        'stop_lon', 'zone_id', 'stop_url', 'location_type', 'parent_station'],
#       dtype='object')
# --------------------

# %% [markdown]
# All the routes operated by CUMTD:

# %%
print('--- {} routes in total ---'.format(len(data['trips']['route_id'].unique())))
data['trips']['route_id'].unique()
# Out:
# --- 100 routes in total ---
# array(['TEAL', 'RED SATURDAY', 'BRONZE', 'TEAL EVENING', 'GREEN',
#        'GREEN EXPRESS', 'YELLOW', 'YELLOWHOPPER', 'GREEN EVENING',
#        'GREY EVENING', 'GREEN LATE NIGHT', 'GREENHOPPER EVENING',
#        'ILLINI EVENING', 'TEAL SUNDAY', 'TEAL LATE NIGHT SUNDAY',
#        '3S LAVENDER ALT', 'GREEN EXPRESS ALT', 'GREENHOPPER',
#        'ILLINI EVENING SATURDAY', 'YELLOW SATURDAY',
#        'YELLOW EVENING SATURDAY', 'GREEN SATURDAY', 'LIME SATURDAY',
#        'LIME EVENING SATURDAY', 'SILVER SUNDAY', 'SILVER EVENING SUNDAY',
#        'LAVENDER SUNDAY', 'BROWN', 'GREEN ALT', 'ORANGE ALT',
#        'ILLINI LIMITED SUNDAY', 'ILLINI EVENING SUNDAY', 'ILLINI',
#        'LAVENDER', 'YELLOW EVENING', '1S YELLOW ALT', 'BLUE', 'PINK',
#        'GREY ALT', '5E GREEN EXPRESS ALT', 'BROWN ALT', 'GREY',
#        'YELLOW SUNDAY', 'YELLOW LATE NIGHT SUNDAY',
#        'YELLOW LATE NIGHT SATURDAY', 'NAVY', 'LIME SUNDAY',
#        '1N YELLOW ALT PM', '5W GREEN EXPRESS 2', 'LAVENDER SATURDAY',
#        'RED', 'GOLD ALT', 'TEAL SATURDAY', 'TEAL EVENING SATURDAY',
#        '5E GREEN EXPRESS 1 ALT', 'ILLINI LIMITED SATURDAY',
#        'ILLINI LIMITED EVENING SATURDAY', '7W GREY ALT', 'LAVENDER ALT',
#        'BROWN ALT PM', 'SILVER LIMITED SUNDAY', 'ORANGE', 'ORANGEHOPPER',
#        'GREENHOPPER EVENING SATURDAY', 'GREEN EVENING SATURDAY',
#        'BRONZE ALT', 'RUBY SUNDAY', 'SILVER SATURDAY',
#        'SILVER EVENING SATURDAY', 'YELLOW LATE NIGHT', 'BROWN ALT1',
#        'SILVER LIMITED SATURDAY', 'SILVER LIMITED EVENING SATURDAY',
#        'LIME EVENING', 'RUBY SATURDAY', 'RUBY EVENING SATURDAY',
#        'GREY SATURDAY', 'GREEN LATE NIGHT SATURDAY',
#        'GREY EVENING SATURDAY', '5W GREEN ALT 2', 'GOLD', 'RAVEN',
#        '7E GREY ALT', 'TEAL LATE NIGHT SATURDAY', 'TEAL LATE NIGHT',
#        'ILLINI LIMITED', 'ILLINI LIMITED EVENING', '1 YELLOW ALT',
#        '10W GOLD ALT', 'RUBY', 'SILVER', 'SILVER LIMITED EVENING',
#        'GOLDHOPPER', 'SILVER EVENING', 'SILVER LATE NIGHT',
#        '1N YELLOW ALT', 'RUBY EVENING', 'GREEN SUNDAY', 'GREY SUNDAY',
#        'GREEN LATE NIGHT SUNDAY'], dtype=object)

# %%
stop_lists = data['stops']['stop_id'].unique()
print("This are {} stops in total.".format(len(stop_lists)))
# Out:
# This are 2496 stops in total.

# %% [markdown]
# ### CUMTD Map
# ---
# #### All Routes Operated by CUMTD

# %%
# all the rounts of CUMTD
plt.rcParams["figure.figsize"] = (20, 20)
plt.plot(data['shapes']['shape_pt_lon'],data['shapes']['shape_pt_lat'], '.b')

# %% [markdown]
# #### All Stops Operated by CUMTD

# %%
# all the stops of CUMTD
plt.rcParams["figure.figsize"] = (10, 10)
plt.plot(data['stops']['stop_lon'],data['stops']['stop_lat'], '.b')

# %% [markdown]
# #### Different CUMTD Routes

# %%
def map_by_route(route = 'TEAL'):
    selected1 = data['trips']['route_id'] == route
    shape_by_route = data['trips'][selected1]['shape_id']
    selected2 = data['shapes']['shape_id'].isin(shape_by_route)
    shape_selected = data['shapes'][selected2]
    selected3 = data['routes']['route_id'] == route
    color = '#' + data['routes'][selected3]['route_color'].values[0]
    plt.plot(shape_selected['shape_pt_lon'],shape_selected['shape_pt_lat'], 
             marker = '.', markersize = 1, alpha = 0.8, linewidth = 0, color = color)

# %%
ipywidgets.interact(map_by_route, route = data['trips']['route_id'].unique().tolist())
# Out:
# <function __main__.map_by_route>

# %% [markdown]
# #### Different Blocks Served by CUMTD

# %%
def stop_by_block(block):
    selected0 = data['trips']['block_id'] == block
    shape_by_block = data['trips'][selected0]['shape_id']
    selected1 = data['shapes']['shape_id'].isin(shape_by_block)
    shape_selected = data['shapes'][selected1]
    plt.plot(shape_selected['shape_pt_lon'],shape_selected['shape_pt_lat'], '.g')

# %%
ipywidgets.interact(stop_by_block, block = data['trips']['block_id'].unique().tolist())
# Out:
# <function __main__.stop_by_block>

# %% [markdown]
# #### Exploration: Putting Relevant Shapes together to Construct a Route

# %%
fig, ax = plt.subplots()
selected1 = data['shapes']['shape_id'].isin(['GN1PO'])
lat1 = data['shapes'][selected1]['shape_pt_lat']
lon1 = data['shapes'][selected1]['shape_pt_lon']
ax.plot(lon1,lat1,'.g')
selected2 = data['shapes']['shape_id'].isin(['5WIUE->'])
lat2 = data['shapes'][selected2]['shape_pt_lat']
lon2 = data['shapes'][selected2]['shape_pt_lon']
ax.plot(lon2,lat2,'.r')
selected3 = data['shapes']['shape_id'].isin(['GREEN 905'])
lat3 = data['shapes'][selected3]['shape_pt_lat']
lon3 = data['shapes'][selected3]['shape_pt_lon']
ax.plot(lon3,lat3,'.b')

# %% [markdown]
# ## Question 1: Bus Travel Speed

# %%
#data['stop_times'].iloc[:100,0:5]

# %% [markdown]
# ### Data Processing
# ---
# #### Pre-processing Data relevant to Question 1.

# %% [markdown]
# ####  1. Convert strings to datetime

# %%
data['stop_times']['arrival_time_cleaned'] = data['stop_times']['arrival_time'].copy()

# %%
data['stop_times']['arrival_time_cleaned'].size
# Out:
# 242858

# %% [markdown]
# 1.1. Replace ill-formated strings like '24:00:00', '25:09:00', or '29:00:02' to correct formats that could be recognized as datetime.

# %%
data['stop_times']['arrival_time_cleaned'] = data['stop_times']['arrival_time'].copy()
for hour in range(24,32):
    rgxs = re.compile(r'^{0}:'.format(hour))
    print("--- Dealing with {0}:00:00 ---".format(hour))
    time_cleaned = np.empty(len(data['stop_times']['arrival_time_cleaned']), dtype=object)
    for idx, t in enumerate(data['stop_times']['arrival_time_cleaned']):
        time_cleaned[idx] = rgxs.sub('0{0}:'.format(hour-24), t)
    data['stop_times']['arrival_time_cleaned'] = time_cleaned

print("--- Done ---")
# Out:
# --- Dealing with 24:00:00 ---
# --- Dealing with 25:00:00 ---
# --- Dealing with 26:00:00 ---
# --- Dealing with 27:00:00 ---
# --- Dealing with 28:00:00 ---
# --- Dealing with 29:00:00 ---
# --- Dealing with 30:00:00 ---
# --- Dealing with 31:00:00 ---
# --- Done ---

# %%
print("Test: ")

idx = 175226

print('Previous Obs.{0}:'.format(idx))
print(data['stop_times']['arrival_time'][idx])
print('Cleaned Obs.{0}:'.format(idx))
print(data['stop_times']['arrival_time_cleaned'][idx])
# Out:
# Test:
# Previous Obs.175226:
# 29:00:00
# Cleaned Obs.175226:
# 05:00:00

# %% [markdown]
# 1.2. Convert string to datetime.

# %%
fmt = "%H:%M:%S"

times = data['stop_times']['arrival_time_cleaned'].tolist()

ts = []

for idx, t in enumerate(times):
    t = datetime.strptime(t,fmt)
    t = t.replace(year=2017)
    ts.append(t)
    
data['stop_times']['times'] = ts

# %%
### A trick to deal with '00:00:00'

time_zero = ['23:59:59','00:00:00']
t_critical = []
for t in time_zero:
    t = datetime.strptime(t,fmt)
    print(t)
    t = t.replace(year=2017)
    print(t)
    t_critical.append(t)
# Out:
# 1900-01-01 23:59:59
# 2017-01-01 23:59:59
# 1900-01-01 00:00:00
# 2017-01-01 00:00:00

# %% [markdown]
# ####  2. Compute travel time between stops

# %% [markdown]
# 2.1. Compute time differnece as arrival time of stop 2 - arrival time of stop 1.

# %%
### this block of codes may take a while to finish

time_between_stops = []
for idx, item in enumerate(data['stop_times']['times']):
        if idx == 0:
            time_between_stops.append(0)
        else:
            time1 = data['stop_times']['times'].iloc[idx]
            time2 = data['stop_times']['times'].iloc[idx - 1]
            time_between_stops.append((time.mktime(time1.timetuple()) - time.mktime(time2.timetuple())) / 60)

# %% [markdown]
# 2.2. Fix some problems.

# %%
### this block of codes may take a while to finish

data['stop_times']['time_between'] = time_between_stops

for idx, item in enumerate(data['stop_times']['time_between']):
    if item < 0:
        
        time1 = data['stop_times']['times'].iloc[idx]
        time0 = data['stop_times']['times'].iloc[idx - 1]
        same_trip = data['stop_times']['trip_id'].iloc[idx] == data['stop_times']['trip_id'].iloc[idx - 1]
        if same_trip:
            time_zero_0 = t_critical[0]
            time_zero_1 = t_critical[1]
            time_corrected = (time.mktime(time_zero_0.timetuple()) - time.mktime(time0.timetuple())) / 60 + (time.mktime(time1.timetuple()) - time.mktime(time_zero_1.timetuple())) / 60
            data['stop_times']['time_between'].iloc[idx] = time_corrected
        else:
            data['stop_times']['time_between'].iloc[idx] = 0
# Out:
# /Users/luol12/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# 2.3. Check if problems all fixed

# %%
wrong_time = []
for idx, item in enumerate(data['stop_times']['time_between']):
    if item < 0:
        
        time1 = data['stop_times']['arrival_time_cleaned'].iloc[idx]
        time0 = data['stop_times']['arrival_time_cleaned'].iloc[idx - 1]
        same_trip = data['stop_times']['trip_id'].iloc[idx] == data['stop_times']['trip_id'].iloc[idx - 1]
        if same_trip:
            print('{0}: arrival time: {1}'.format(idx - 1,time0))
            print('-'*6+' Same Trip: {}'.format(same_trip))
            print('{0}: arrival time: {1}'.format(idx,time1))
            print('{0}: arrival time (original): {1}'.format(idx,data['stop_times']['arrival_time'].iloc[idx]))
            print('{0}: converted time: {1}'.format(idx,data['stop_times']['times'].iloc[idx]))
            print('time between: {0}'.format(item))
            print('-'*30)
            wrong_time.append((idx, item))

# %%
print('Number of wrong time: {}'.format(len(wrong_time)))
# Out:
# Number of wrong time: 0

# %% [markdown]
# ### Building Functions
# ---
# #### Building some functions to facilitate data visualization.

# %%
def get_stop_latlon(stop):
    match = data['stops']['stop_id'] == stop
    stop_lat = data['stops'][match]['stop_lat'].values[0]
    stop_lon = data['stops'][match]['stop_lon'].values[0]
    return stop_lon, stop_lat

# %%
def get_stop_name(stop):
    match = data['stops']['stop_id'] == stop
    stop_name = data['stops'][match]['stop_name'].values[0]
    return stop_name

# %%
print(get_stop_name('ODSS:1'))
# Out:
# Orchard Downs South Shelter

# %%
print(get_stop_latlon('ODSS:1'))
# Out:
# (-88.211043329999995, 40.09090667000001)

# %%
def get_stops_positions(stoplist, use_stop_name = False):
    
    stop_pos = {}
    
    for stop in stoplist:
        if use_stop_name:
            tag = get_stop_name(stop)
        else:
            tag = stop
            
        stop_lon, stop_lat = get_stop_latlon(stop)
        stop_pos[tag] = stop_lon, stop_lat
        
    return stop_pos

# %%
def get_route_color(route):
    selected = data['routes']['route_id'] == route
    color = '#' + data['routes'][selected]['route_color'].values[0]
    return color

# %%
def get_trips_on_route(route):
    selected = data['trips']['route_id'] == route
    trips = data['trips'][selected]['trip_id']
    return trips

# %%
def get_directions_on_route(route):
    selected = data['trips']['route_id'] == route
    directions = data['trips'][selected]['direction_id']
    return directions

# %%
def get_directed_trips(route, direction = 1):
    trips_2 = get_trips_on_route(route)
    direct = get_directions_on_route(route)
    trips = trips_2[direct == direction]
    return trips

# %%
def get_stops_on_route(route, direction = 1):
    trips = get_directed_trips(route, direction = direction)
    stoplist = []
    for trip in trips:
        selected =  data['stop_times']['trip_id'] == trip
        stoplist.extend(data['stop_times'][selected]['stop_id'])
    return stoplist

# %%
def get_shape_of_route(route, direction = 1):
    trips = get_directed_trips(route)
    selected1 = data['trips']['trip_id'].isin(trips)
    shape_by_route = data['trips'][selected1]['shape_id'].unique()
    return shape_by_route

# %%
def get_stop_pairs():
    stop_network = {}
    stops_by_trip = data['stop_times'].groupby('trip_id')
    for trip_id, trip in stops_by_trip:
        stop_network[trip_id] = []
        print('Dealing with trip {} ...'.format(trip_id))
        stop_ids = trip['stop_id']
        travel_times = trip['time_between']
        #travel_times = time_travel[trip_id]
        for idx, item in enumerate(stop_ids):
            if idx != 0:
                stop_network[trip_id].append(((stop_ids.iloc[idx-1],stop_ids.iloc[idx]),travel_times.iloc[idx]))
    
    return stop_network

# %% [markdown]
# #### Get all pairs of connected stop

# %%
# This may take a few seconds to finish

stop_network = get_stop_pairs()
# Out:
# Dealing with trip 1GN500__GN1_MF ...
# Dealing with trip 1GN507__GN1_MF ...
# Dealing with trip 1GN508__GN1_MF ...
# Dealing with trip 1GN509__GN1_MF ...
# Dealing with trip 1GN510__GN1_MF ...
# Dealing with trip 1GN511__GN1_MF ...
# Dealing with trip 1GN512__GN1_MF ...
# Dealing with trip 1GN513__GN1_MF ...
# Dealing with trip 1GN514__GN1_MF ...
# Dealing with trip 1GN515__GN1_MF ...
# Dealing with trip 1GN516__GN1_MF ...
# Dealing with trip 1GN517__GN1_MF ...
# Dealing with trip 1GNX100__Y4_MF ...
# Dealing with trip 1GNX102__GNX1_NOSCHMF ...
# Dealing with trip 1GNX102__GNX1_SCHMF ...
# Dealing with trip 20RED001__R1SA ...
# Dealing with trip 20RED002__R1SA ...
# Dealing with trip 20RED003__R1SA ...
# Dealing with trip 20RED004__R1SA ...
# Dealing with trip 20RED005__R1SA ...
# Dealing with trip 20RED006__R1SA ...
# Dealing with trip 20RED007__R1SA ...
# Dealing with trip 20RED008__R1SA ...
# Dealing with trip 20RED009__R1SA ...
# Dealing with trip 20RED010__R1SA ...
# Dealing with trip 20RED011__R1SA ...
# Dealing with trip 20RED012__R1SA ...
# Dealing with trip 20RED013__R1SA ...
# Dealing with trip 20RED014__R1SA ...
# Dealing with trip 20RED015__R1SA ...
# Dealing with trip 20RED016__R1SA ...
# Dealing with trip 20RED018__R2SA ...
# Dealing with trip 20RED019__R2SA ...
# Dealing with trip 20RED020__R2SA ...
# Dealing with trip 20RED021__R2SA ...
# Dealing with trip 20RED022__R2SA ...
# Dealing with trip 20RED023__R2SA ...
# Dealing with trip 20RED024__R2SA ...
# Dealing with trip 20RED025__R2SA ...
# Dealing with trip 20RED026__R2SA ...
# Dealing with trip 20RED027__R2SA ...
# Dealing with trip 20RED028__R2SA ...
# Dealing with trip 20RED029__R2SA ...
# Dealing with trip 20RED030__R2SA ...
# Dealing with trip 20RED031__R2SA ...
# Dealing with trip 20RED032__R2SA ...
# Dealing with trip 20RED033__R2SA ...
# Dealing with trip 20RED034__R3SA ...
# Dealing with trip 20RED035__R3SA ...
# Dealing with trip 20RED036__R3SA ...
# Dealing with trip 20RED037__R3SA ...
# Dealing with trip 20RED038__R3SA ...
# Dealing with trip 20RED039__R3SA ...
# Dealing with trip 20RED040__R3SA ...
# Dealing with trip 20RED041__R3SA ...
# Dealing with trip 20RED042__R3SA ...
# Dealing with trip 20RED043__R3SA ...
# Dealing with trip 20RED044__R3SA ...
# Dealing with trip 20RED045__R3SA ...
# Dealing with trip 20RED046__R3SA ...
# Dealing with trip 20RED047__R3SA ...
# Dealing with trip 20RED048__R3SA ...
# Dealing with trip 23S200__GR2_MF ...
# Dealing with trip 2GN530__GN2_MF ...
# Dealing with trip 2GN531__GN2_MF ...
# Dealing with trip 2GN535__GN2_MF ...
# Dealing with trip 2GN536__GN2_MF ...
# Dealing with trip 2GN537__GN2_MF ...
# Dealing with trip 2GN538__GN2_MF ...
# Dealing with trip 2GN539__GN2_MF ...
# Dealing with trip 2GN540__GN2_MF ...
# Dealing with trip 2GN541__GN2_MF ...
# Dealing with trip 2GN542__GN2_MF ...
# Dealing with trip 2GN543__GN2_MF ...
# Dealing with trip 2GN544__GN2_MF ...
# Dealing with trip 2GN545__GN2_MF ...
# Dealing with trip 2GR722__GR1_NOSCHMF ...
# Dealing with trip 2GR723.5__GR1_NOSCHMF ...
# Dealing with trip 2GR723.5__GR1_SCHMF ...
# Dealing with trip 2GR723__GR1_NOSCHMF ...
# Dealing with trip 2GR723__GR1_SCHMF ...
# Dealing with trip 2GR741__GR4_MF ...
# Dealing with trip 2GR745__GR3_NONUIMF ...
# Dealing with trip 2GR745__GR3_UIMF ...
# Dealing with trip 2GR746__GR1_NOSCHMF ...
# Dealing with trip 2GR746__GR1_SCHMF ...
# Dealing with trip 3GN305__GN3_NOSCHMF ...
# Dealing with trip 3GN305__GN3_SCHMF ...
# Dealing with trip 3GN306__GN3_NOSCHMF ...
# Dealing with trip 3GN306__GN3_SCHMF ...
# Dealing with trip 3GN308__BZ1_NOSCHMF ...
# Dealing with trip 3GN308__BZ1_SCHMF ...
# Dealing with trip 3GN309__GR3_NONUIMF ...
# Dealing with trip 3GN309__GR3_UIMF ...
# Dealing with trip 3GN312__GR4_MF ...
# Dealing with trip 3GR7004__Y7_UIF ...
# Dealing with trip 3GR788__GR3_UIMF ...
# Dealing with trip 3GR799__Y7_UIF ...
# Dealing with trip 3R300__B1_MF ...
# Dealing with trip 3R301__B1_MF ...
# Dealing with trip 3R302__B1_MF ...
# Dealing with trip 3R303__B1_MF ...
# Dealing with trip 4GN582__I8/4S_NOSCH_NOUI ...
# Dealing with trip 4GN582__I8/4S_NOSCH_UIF ...
# Dealing with trip 4GN582__I8/4S_SCHMTH_NOUI ...
# Dealing with trip 4GN582__I8/4S_SCHWED ...
# Dealing with trip 4GN582__I8/4S_SCHWED_NOUI ...
# Dealing with trip 4GN582__I8/4S_SCH_UI ...
# Dealing with trip 4GN582__I8/4S_SCH_UIF ...
# Dealing with trip 4GN582__I8/4S_UIMTH_SCH ...
# Dealing with trip 4GR781__GNX5_MF ...
# Dealing with trip 5GN560__GN5_MF ...
# Dealing with trip 5GN561__GN5_MF ...
# Dealing with trip 5GN562__GN5_MF ...
# Dealing with trip 5GN563__GN5_MF ...
# Dealing with trip 5GN564__GN5_MF ...
# Dealing with trip 5GN565__GN5_MF ...
# Dealing with trip 5GN566__GN5_MF ...
# Dealing with trip 5GN567__GN5_MF ...
# Dealing with trip 5GN568__GN5_MF ...
# Dealing with trip 5GN569__GN5_MF ...
# Dealing with trip 5GN570__GN5_MF ...
# Dealing with trip 5GN571__GN5_MF ...
# Dealing with trip 5GN572__GN5_MF ...
# Dealing with trip 5GN575__GN5_MF ...
# Dealing with trip 5GN576__GN5_MF ...
# Dealing with trip 5GN577__GN5_MF ...
# Dealing with trip 5GNX202__GNX2_MF ...
# Dealing with trip 5GNX301__GNX3_MF ...
# Dealing with trip 5GNX302__GNX3_MF ...
# Dealing with trip 5GNX303__GNX3_MF ...
# Dealing with trip 5GNX304__I8/4S_NOSCH_NOUI ...
# Dealing with trip 5GNX304__I8/4S_NOSCH_UIF ...
# Dealing with trip 5GNX304__I8/4S_SCHMTH_NOUI ...
# Dealing with trip 5GNX304__I8/4S_SCHWED ...
# Dealing with trip 5GNX304__I8/4S_SCHWED_NOUI ...
# Dealing with trip 5GNX304__I8/4S_SCH_UI ...
# Dealing with trip 5GNX304__I8/4S_SCH_UIF ...
# Dealing with trip 5GNX304__I8/4S_UIMTH_SCH ...
# Dealing with trip 5GNX306__I8/4S_NOSCH_NOUI ...
# Dealing with trip 5GNX306__I8/4S_NOSCH_UIF ...
# Dealing with trip 5GNX306__I8/4S_SCHMTH_NOUI ...
# Dealing with trip 5GNX306__I8/4S_SCHWED ...
# Dealing with trip 5GNX306__I8/4S_SCHWED_NOUI ...
# Dealing with trip 5GNX306__I8/4S_SCH_UI ...
# Dealing with trip 5GNX306__I8/4S_SCH_UIF ...
# Dealing with trip 5GNX306__I8/4S_UIMTH_SCH ...
# Dealing with trip 5R518__GN8_NOSCHMF ...
# Dealing with trip 5R518__GN8_SCH_MTTF ...
# Dealing with trip 5R518__GN8_SCH_WED ...
# Dealing with trip 7GN500__GNX1_NOSCHMF ...
# Dealing with trip 7GN500__GNX1_SCHMF ...
# Dealing with trip 7GN501__GNX1_NOSCHMF ...
# Dealing with trip 7GN501__GNX1_SCHMF ...
# Dealing with trip 7R719__GR1_NOSCHMF ...
# Dealing with trip 7R719__GR1_SCHMF ...
# Dealing with trip 7R720__GR4_MF ...
# Dealing with trip 8GN502__GN7_MF ...
# Dealing with trip 8GN503__GN7_MF ...
# Dealing with trip 8GN504__GN7_MF ...
# Dealing with trip 8GN505__GN7_MF ...
# Dealing with trip 8GN506__GN7_MF ...
# Dealing with trip 8GN507__GN7_MF ...
# Dealing with trip 8GN508__GN7_MF ...
# Dealing with trip 8GN509__GN7_MF ...
# Dealing with trip 8GN510__GN7_MF ...
# Dealing with trip 8GN511__GN7_MF ...
# Dealing with trip 8GN514__GNX4_MF ...
# Dealing with trip 8GN515__GNX4_MF ...
# Dealing with trip 8GN518__GR4_MF ...
# Dealing with trip 8GN519__BZ1_NOSCHMF ...
# Dealing with trip 8GN519__BZ1_SCHMF ...
# Dealing with trip 8GN522__GR1_NOSCHMF ...
# Dealing with trip 8GN522__GR1_SCHMF ...
# Dealing with trip 8GN525__Y7_NONUIMF ...
# Dealing with trip 8GN525__Y7_UIF ...
# Dealing with trip 8GN525__Y7_UIMTH ...
# Dealing with trip 8GN526__Y7_UIF ...
# Dealing with trip 8GN526__Y7_UIMTH ...
# Dealing with trip 8GN527__Y7_UIF ...
# Dealing with trip 8GN527__Y7_UIMTH ...
# Dealing with trip 8GN531__GR3_UIMF ...
# Dealing with trip 8GN535__Y7_UIF ...
# Dealing with trip 8GN535__Y7_UIMTH ...
# Dealing with trip 8GN539__Y7_UIF ...
# Dealing with trip 8GN543__Y7_UIF ...
# Dealing with trip BA4-6__GR1_NOSCHMF ...
# Dealing with trip BA4-6__GR1_SCHMF ...
# Dealing with trip BA4-9__BZ1_NOSCHMF ...
# Dealing with trip BA4-9__BZ1_SCHMF ...
# Dealing with trip GN1PO__GN1_MF ...
# Dealing with trip GN1SAT006__GR4SA ...
# Dealing with trip GN1SAT006__GR4SA_EVE ...
# Dealing with trip GN1SAT010__GN4SA ...
# Dealing with trip GN1SAT010__GN4SA_EVE ...
# Dealing with trip GN1SAT014__GN2NONUISA ...
# Dealing with trip GN1SAT014__GN2NONUISA_EVE ...
# Dealing with trip GN1SAT014__GN2UISA ...
# Dealing with trip GN1SAT018__GR3_SA ...
# Dealing with trip GN1SAT018__GR3_SA_EVE ...
# Dealing with trip GN1SAT030__GN1SA ...
# Dealing with trip GN1SAT030__GN1SA_EVE ...
# Dealing with trip GN1SATPO__GN1SA ...
# Dealing with trip GN1SATPO__GN1SA_EVE ...
# Dealing with trip GN2PO__GN2_MF ...
# Dealing with trip GN2SAT008__GR2SA ...
# Dealing with trip GN2SAT008__GR2SA_EVE ...
# Dealing with trip GN2SAT012__GR1SA ...
# Dealing with trip GN2SAT012__GR1SA_EVE ...
# Dealing with trip GN2SAT016__GN3NONUISA ...
# Dealing with trip GN2SAT016__GN3NONUISA_EVE ...
# Dealing with trip GN2SAT016__GN3UISA ...
# Dealing with trip GN2SAT020__GR4SA ...
# Dealing with trip GN2SAT020__GR4SA_EVE ...
# Dealing with trip GN2SATPO__LM1SA ...
# Dealing with trip GN2SATPO__LM1SA_EVE ...
# Dealing with trip GN3SAT000__GN2NONUISA ...
# Dealing with trip GN3SAT000__GN2NONUISA_EVE ...
# Dealing with trip GN3SAT000__GN2UISA ...
# Dealing with trip GN3SAT004__GR3_SA ...
# Dealing with trip GN3SAT004__GR3_SA_EVE ...
# Dealing with trip GN3SAT008__GN1SA ...
# Dealing with trip GN3SAT008__GN1SA_EVE ...
# Dealing with trip GN3SAT012__GR2SA ...
# Dealing with trip GN3SAT012__GR2SA_EVE ...
# Dealing with trip GN3SAT016__GR1SA ...
# Dealing with trip GN3SAT016__GR1SA_EVE ...
# Dealing with trip GN3SATPO__GN2NONUISA ...
# Dealing with trip GN3SATPO__GN2NONUISA_EVE ...
# Dealing with trip GN3SATPO__GN2UISA ...
# Dealing with trip GN4SAT000__GR1SA ...
# Dealing with trip GN4SAT000__GR1SA_EVE ...
# Dealing with trip GN4SAT004__GN2NONUISA ...
...
# Dealing with trip [@7.0.42019048@][1245177724421]/78__GN1SA ...
# Dealing with trip [@7.0.42019048@][1245177724421]/7__GN1SA ...
# Dealing with trip [@7.0.42019048@][3][1256063201375]/0__GN1SA ...
# Dealing with trip [@7.0.42019048@][4][1256062571281]/0__GN2NONUISA ...
# Dealing with trip [@7.0.42019048@][4][1256062571281]/0__GN2UISA ...
# Dealing with trip [@7.0.42019048@][4][1256062611953]/1__GR4SA ...
# Dealing with trip [@7.0.42019048@][4][1256062611953]/2__GN5SA ...
# Dealing with trip [@7.0.42019048@][4][1256062611953]/3__GN2NONUISA ...
# Dealing with trip [@7.0.42019048@][4][1256062611953]/3__GN2UISA ...
# Dealing with trip [@7.0.42019048@][4][1256062670781]/4__GN5SA ...
# Dealing with trip [@7.0.42019048@][4][1256063002359]/0__GN2NONUISA ...
# Dealing with trip [@7.0.42019048@][4][1256063002359]/0__GN2UISA ...

# %%
def select_pairs_by_route(route, direction = 1):
    trips = get_directed_trips(route, direction = direction)
    #stop_network = get_stop_pairs()
    pair_in_route = []
    for trip in trips:
        pair_in_route.extend(stop_network[trip])
        
    return pair_in_route

# %%
print('Test:')
route = 'TEAL'
print('Total trips on route {0}: {1}'.format(route,len(get_trips_on_route(route))))
print('Total stops on route {0}: {1}'.format(route,len(get_stops_on_route(route))))
print('Total pairs on route {0}: {1}'.format(route,len(select_pairs_by_route(route))))
pairs = select_pairs_by_route(route)
print('First pair ((Stop1, Stop2), Travel Time): {}'.format(pairs[0]))
# Out:
# Test:
# Total trips on route TEAL: 238
# Total stops on route TEAL: 2460
# Total pairs on route TEAL: 2336
# First pair ((Stop1, Stop2), Travel Time): (('DEPOT:1', 'PAR:2'), 10.0)

# %% [markdown]
# ### Data Visualization: Different Routes and Stops on Routes (edges indicating travel time)
# ----
# The width of the edge connecting two stops indicate how long it takes from one stop to the next.

# %%
def create_graph_by_route(route = 'GREEN', direction = 1):
    
    # initiate a graph
    g = nx.Graph()

    # get stop pairs
    pairs = select_pairs_by_route(route, direction = direction)

    # add edges
    for (stop1, stop2), weight in pairs:
        g.add_edge(stop1, stop2, weight=weight)

    return g

# %%
def draw_graph_by_route(g, route = 'GREEN', direction = 1):
    
    # some image formatting
    fig, ax = plt.subplots(figsize=(10, 10))
    #sns.despine(ax=ax, top = True, bottom = True, left = True, right = True)
    #ax.set_xticklabels([])
    #ax.set_yticklabels([])
    
    # draw the shape of the route
    map_by_route(route) 
    
    # the positions of all nodes
    stoplist = get_stops_on_route(route, direction = direction)
    pos = get_stops_positions(stoplist)
    
    # set the color of the nodes and edges
    clr = get_route_color(route)

    # draw the nodes
    nx.draw_networkx_nodes(g, pos, with_labels=True,
                       node_color=clr, node_size = 10,
                       alpha = 1)
    
    # draw the edges
    edges = []
    weights = []

    for n1, n2, dct in g.edges(data=True):
        edges.append((n1, n2))
        weights.append(dct['weight']*2)
    
    # select edges 
    edges_selected = []
    for idx, weight in enumerate(weights):
        if weight < 5:
            edges_selected.append(edges[idx])

    nx.draw_networkx_edges(g, pos, 
                       width = weights, edgelist = edges_selected, 
                       edge_color = [clr]*len(edges_selected),
                       alpha = 0.6)
    
    # add labels
    #nx.draw_networkx_labels(g, pos, alpha = 1.0, font = 0.1)
    
    return ax

# %%
def get_route_graph(route = 'GREEN', direction = 1):
    g = create_graph_by_route(route = route, direction = direction)
    route_ax = draw_graph_by_route(g, route = route, direction = direction)
    return route_ax

# %%
ipywidgets.interact(get_route_graph, route = data['trips']['route_id'].unique().tolist(), direction = [0,1])
# Out:
# <function __main__.get_route_graph>

# %% [markdown]
# ### Data Visualization: Descriptive Statistics
# ---
# Get descriptive statistics and data visualization on the statistics

# %%
shape_by_id = data['shapes'].groupby('shape_id')
dist_by_shape = shape_by_id['shape_dist_traveled'].max()

def average_speed_by_route(route, direction = 1):
    route_shapes = get_shape_of_route(route, direction = direction)
    route_dist = 0
    for shape in route_shapes:
        route_dist += dist_by_shape[shape]
    pairs = select_pairs_by_route(route, direction = direction)
    route_time = 0
    for (stop1,stop2), time in pairs:
        route_time += time
    if route_time != 0:
        route_speed = route_dist/route_time
    else:
        route_speed = 'Not Applicable'
    return route_dist,route_time,route_speed

# %% [markdown]
# #### 1. Summary: Average speed by route

# %%
for route in data['routes']['route_id'].unique().tolist():
    route_dist,route_time,route_speed = average_speed_by_route(route = route)
    print('Route {0}'.format(route))
    if route_time != 0:
        print('Avg Speed: {0:5.3f} m/min'.format(route_speed))
    if route_time == 0:
        print('Avg Speed: {0}'.format(route_speed))
    print('Total Time: {0:5.3f} mins'.format(route_time))
    print('Total Dist: {0:5.3f} ms'.format(route_dist))
    print('-'*30)
# Out:
# Route GOLD ALT
# Avg Speed: 608.700 m/min
# Total Time: 27.500 mins
# Total Dist: 16739.240 ms
# ------------------------------
# Route RUBY SATURDAY
# Avg Speed: 38.150 m/min
# Total Time: 367.000 mins
# Total Dist: 14000.955 ms
# ------------------------------
# Route SILVER LIMITED SATURDAY
# Avg Speed: 14.117 m/min
# Total Time: 343.000 mins
# Total Dist: 4842.199 ms
# ------------------------------
# Route BROWN ALT PM
# Avg Speed: 346.292 m/min
# Total Time: 101.000 mins
# Total Dist: 34975.532 ms
# ------------------------------
# Route YELLOW LATE NIGHT SUNDAY
# Avg Speed: 33.625 m/min
# Total Time: 477.983 mins
# Total Dist: 16072.121 ms
# ------------------------------
# Route GREEN EVENING SATURDAY
# Avg Speed: 55.628 m/min
# Total Time: 749.000 mins
# Total Dist: 41665.224 ms
# ------------------------------
# Route GREY ALT
# Avg Speed: 207.316 m/min
# Total Time: 359.833 mins
# Total Dist: 74599.217 ms
# ------------------------------
# Route TEAL LATE NIGHT SUNDAY
# Avg Speed: 11.055 m/min
# Total Time: 512.983 mins
# Total Dist: 5670.837 ms
# ------------------------------
# Route GREEN LATE NIGHT SATURDAY
# Avg Speed: 51.847 m/min
# Total Time: 195.000 mins
# Total Dist: 10110.123 ms
# ------------------------------
# Route 5E GREEN EXPRESS 1 ALT
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route GREEN SATURDAY
# Avg Speed: 20.158 m/min
# Total Time: 3184.000 mins
# Total Dist: 64182.544 ms
# ------------------------------
# Route 3S LAVENDER ALT
# Avg Speed: 187.665 m/min
# Total Time: 230.000 mins
# Total Dist: 43162.877 ms
# ------------------------------
# Route SILVER LIMITED SUNDAY
# Avg Speed: 19.139 m/min
# Total Time: 253.000 mins
# Total Dist: 4842.199 ms
# ------------------------------
# Route SILVER EVENING SUNDAY
# Avg Speed: 26.913 m/min
# Total Time: 396.983 mins
# Total Dist: 10683.956 ms
# ------------------------------
# Route LIME EVENING SATURDAY
# Avg Speed: 163.750 m/min
# Total Time: 254.000 mins
# Total Dist: 41592.603 ms
# ------------------------------
# Route ILLINI EVENING SUNDAY
# Avg Speed: 7.504 m/min
# Total Time: 1788.933 mins
# Total Dist: 13424.732 ms
# ------------------------------
# Route GREENHOPPER EVENING SATURDAY
# Avg Speed: 90.400 m/min
# Total Time: 397.000 mins
# Total Dist: 35888.859 ms
# ------------------------------
# Route YELLOW SUNDAY
# Avg Speed: 43.853 m/min
# Total Time: 1701.000 mins
# Total Dist: 74593.965 ms
# ------------------------------
# Route TEAL SATURDAY
# Avg Speed: 7.362 m/min
# Total Time: 2094.000 mins
# Total Dist: 15416.606 ms
# ------------------------------
# Route LAVENDER ALT
# Avg Speed: 311.908 m/min
# Total Time: 157.500 mins
# Total Dist: 49125.473 ms
# ------------------------------
# Route YELLOW
# Avg Speed: 39.690 m/min
# Total Time: 2537.000 mins
# Total Dist: 100693.130 ms
# ------------------------------
# Route RED
# Avg Speed: 150.172 m/min
# Total Time: 1590.000 mins
# Total Dist: 238774.038 ms
# ------------------------------
# Route 5E GREEN EXPRESS ALT
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route SILVER SUNDAY
# Avg Speed: 26.405 m/min
# Total Time: 461.000 mins
# Total Dist: 12172.526 ms
# ------------------------------
# Route GREENHOPPER
# Avg Speed: 75.605 m/min
# Total Time: 1195.000 mins
# Total Dist: 90348.150 ms
# ------------------------------
# Route GREEN
# Avg Speed: 140.301 m/min
# Total Time: 1733.783 mins
# Total Dist: 243252.121 ms
# ------------------------------
# Route RUBY SUNDAY
# Avg Speed: 53.034 m/min
# Total Time: 264.000 mins
# Total Dist: 14000.955 ms
# ------------------------------
# Route LAVENDER SUNDAY
# Avg Speed: 41.588 m/min
# Total Time: 540.000 mins
# Total Dist: 22457.540 ms
# ------------------------------
# Route BRONZE YANKEE RIDGE
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route LAVENDER SATURDAY
# Avg Speed: 19.984 m/min
# Total Time: 639.000 mins
# Total Dist: 12770.005 ms
# ------------------------------
# Route TEAL LATE NIGHT SATURDAY
# Avg Speed: 37.312 m/min
# Total Time: 151.983 mins
# Total Dist: 5670.837 ms
# ------------------------------
# Route GREY SATURDAY
# Avg Speed: 8.291 m/min
# Total Time: 3070.000 mins
# Total Dist: 25452.928 ms
# ------------------------------
# Route GREEN EXPRESS ALT
# Avg Speed: 307.275 m/min
# Total Time: 63.000 mins
# Total Dist: 19358.337 ms
# ------------------------------
# Route GREENHOPPER EVENING
# Avg Speed: 85.497 m/min
# Total Time: 413.000 mins
# Total Dist: 35310.122 ms
# ------------------------------
# Route GOLD
# Avg Speed: 138.958 m/min
# Total Time: 1279.000 mins
# Total Dist: 177727.500 ms
# ------------------------------
# Route YELLOW EVENING SATURDAY
# Avg Speed: 67.944 m/min
# Total Time: 1002.967 mins
# Total Dist: 68145.211 ms
# ------------------------------
# Route BROWN ALT
# Avg Speed: 423.071 m/min
# Total Time: 90.000 mins
# Total Dist: 38076.385 ms
# ------------------------------
# Route PINK
# Avg Speed: 39.569 m/min
# Total Time: 1486.000 mins
# Total Dist: 58799.666 ms
# ------------------------------
# Route GREY EVENING
# Avg Speed: 74.690 m/min
# Total Time: 835.000 mins
# Total Dist: 62365.860 ms
# ------------------------------
# Route 5W GREEN ALT 2
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route SILVER
# Avg Speed: 3.088 m/min
# Total Time: 2471.000 mins
# Total Dist: 7631.223 ms
# ------------------------------
# Route RUBY EVENING SATURDAY
# Avg Speed: 241.831 m/min
# Total Time: 108.000 mins
# Total Dist: 26117.786 ms
# ------------------------------
# Route GREY EVENING SATURDAY
# Avg Speed: 50.870 m/min
# Total Time: 551.000 mins
# Total Dist: 28029.448 ms
# ------------------------------
# Route ORANGEHOPPER
# Avg Speed: 27.470 m/min
# Total Time: 365.000 mins
# Total Dist: 10026.487 ms
# ------------------------------
# Route RUBY
# Avg Speed: 27.917 m/min
# Total Time: 399.000 mins
# Total Dist: 11138.968 ms
# ------------------------------
# Route ILLINI
# Avg Speed: 6.501 m/min
# Total Time: 4081.000 mins
# Total Dist: 26528.600 ms
# ------------------------------
# Route ILLINI LIMITED SUNDAY
# Avg Speed: 9.494 m/min
# Total Time: 468.000 mins
# Total Dist: 4443.376 ms
# ------------------------------
# Route GREY
# Avg Speed: 35.739 m/min
# Total Time: 1950.000 mins
# Total Dist: 69690.081 ms
# ------------------------------
# Route 7E GREY ALT
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route ILLINI LIMITED
# Avg Speed: 29.163 m/min
# Total Time: 303.000 mins
# Total Dist: 8836.245 ms
# ------------------------------
# Route BROWN
# Avg Speed: 103.286 m/min
# Total Time: 1546.933 mins
# Total Dist: 159776.973 ms
# ------------------------------
# Route 1N YELLOW ALT PM
# Avg Speed: 375.025 m/min
# Total Time: 65.000 mins
# Total Dist: 24376.647 ms
# ------------------------------
# Route TEAL LATE NIGHT
# Avg Speed: 24.874 m/min
# Total Time: 227.983 mins
# Total Dist: 5670.837 ms
# ------------------------------
# Route ORANGE
# Avg Speed: 98.698 m/min
# Total Time: 1033.000 mins
# Total Dist: 101955.472 ms
# ------------------------------
# Route YELLOW EVENING
# Avg Speed: 102.409 m/min
# Total Time: 1146.967 mins
# Total Dist: 117460.088 ms
# ------------------------------
# Route 1 YELLOW ALT
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route RED SATURDAY
# Avg Speed: 45.654 m/min
# Total Time: 1011.000 mins
# Total Dist: 46156.080 ms
# ------------------------------
# Route GREEN ALT
# Avg Speed: 193.119 m/min
# Total Time: 102.000 mins
# Total Dist: 19698.090 ms
# ------------------------------
# Route YELLOW LATE NIGHT SATURDAY
# Avg Speed: 116.519 m/min
# Total Time: 227.500 mins
# Total Dist: 26508.111 ms
# ------------------------------
# Route YELLOW LATE NIGHT
# Avg Speed: 79.961 m/min
# Total Time: 201.000 mins
# Total Dist: 16072.121 ms
# ------------------------------
# Route GREEN EVENING
# Avg Speed: 92.438 m/min
# Total Time: 939.000 mins
# Total Dist: 86799.546 ms
# ------------------------------
# Route BLUE
# Avg Speed: 14.052 m/min
# Total Time: 1198.000 mins
# Total Dist: 16834.722 ms
# ------------------------------
# Route SILVER LIMITED EVENING SATURDAY
# Avg Speed: 21.105 m/min
# Total Time: 160.000 mins
# Total Dist: 3376.827 ms
# ------------------------------
# Route YELLOW SATURDAY
# Avg Speed: 11.542 m/min
# Total Time: 3897.000 mins
# Total Dist: 44977.346 ms
# ------------------------------
# Route LIME SATURDAY
# Avg Speed: 48.893 m/min
# Total Time: 1678.000 mins
# Total Dist: 82042.079 ms
# ------------------------------
# Route TEAL EVENING SATURDAY
# Avg Speed: 9.971 m/min
# Total Time: 570.000 mins
# Total Dist: 5683.603 ms
# ------------------------------
# Route TEAL EVENING
# Avg Speed: 7.872 m/min
# Total Time: 722.000 mins
# Total Dist: 5683.603 ms
# ------------------------------
# Route ILLINI EVENING SATURDAY
# Avg Speed: 6.111 m/min
# Total Time: 2196.933 mins
# Total Dist: 13424.732 ms
# ------------------------------
# Route SILVER EVENING
# Avg Speed: 23.850 m/min
# Total Time: 447.967 mins
# Total Dist: 10683.956 ms
# ------------------------------
# Route GREEN LATE NIGHT SUNDAY
# Avg Speed: 21.240 m/min
# Total Time: 238.000 mins
# Total Dist: 5055.062 ms
# ------------------------------
# Route BRONZE ALT
# Avg Speed: 358.012 m/min
# Total Time: 94.500 mins
# Total Dist: 33832.093 ms
# ------------------------------
# Route NAVY
# Avg Speed: 48.919 m/min
# Total Time: 306.000 mins
# Total Dist: 14969.118 ms
# ------------------------------
# Route LIME SUNDAY
# Avg Speed: 42.049 m/min
# Total Time: 457.000 mins
# Total Dist: 19216.349 ms
# ------------------------------
# Route ILLINI LIMITED EVENING SATURDAY
# Avg Speed: 34.180 m/min
# Total Time: 130.000 mins
# Total Dist: 4443.376 ms
# ------------------------------
# Route GREEN LATE NIGHT
# Avg Speed: 35.474 m/min
# Total Time: 285.000 mins
# Total Dist: 10110.123 ms
# ------------------------------
# Route GREY SUNDAY
# Avg Speed: 34.284 m/min
# Total Time: 1220.000 mins
# Total Dist: 41826.418 ms
# ------------------------------
# Route SILVER LATE NIGHT
# Avg Speed: 28.779 m/min
# Total Time: 372.000 mins
# Total Dist: 10705.924 ms
# ------------------------------
# Route 10W GOLD ALT
# Avg Speed: 512.386 m/min
# Total Time: 37.000 mins
# Total Dist: 18958.287 ms
# ------------------------------
# Route TEAL SUNDAY
# Avg Speed: 14.997 m/min
# Total Time: 1028.000 mins
# Total Dist: 15416.606 ms
# ------------------------------
# Route ILLINI LIMITED EVENING
# Avg Speed: 34.180 m/min
# Total Time: 130.000 mins
# Total Dist: 4443.376 ms
# ------------------------------
# Route SILVER EVENING SATURDAY
# Avg Speed: 21.939 m/min
# Total Time: 486.983 mins
# Total Dist: 10683.956 ms
# ------------------------------
# Route RUBY EVENING
# Avg Speed: 81.856 m/min
# Total Time: 339.000 mins
# Total Dist: 27749.213 ms
# ------------------------------
# Route GREEN SUNDAY
# Avg Speed: 48.254 m/min
# Total Time: 1168.000 mins
# Total Dist: 56360.192 ms
# ------------------------------
# Route GOLDHOPPER
# Avg Speed: 8.026 m/min
# Total Time: 616.000 mins
# Total Dist: 4943.915 ms
# ------------------------------
# Route SILVER SATURDAY
# Avg Speed: 22.335 m/min
# Total Time: 545.000 mins
# Total Dist: 12172.526 ms
# ------------------------------
# Route BRONZE
# Avg Speed: 41.217 m/min
# Total Time: 845.000 mins
# Total Dist: 34828.553 ms
# ------------------------------
# Route 5W GREEN EXPRESS 2
# Avg Speed: 421.921 m/min
# Total Time: 184.000 mins
# Total Dist: 77633.392 ms
# ------------------------------
# Route BROWN ALT1
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route 1N YELLOW ALT
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route 1S YELLOW ALT
# Avg Speed: 341.051 m/min
# Total Time: 163.000 mins
# Total Dist: 55591.374 ms
# ------------------------------
# Route RAVEN
# Avg Speed: Not Applicable
# Total Time: 0.000 mins
# Total Dist: 0.000 ms
# ------------------------------
# Route ILLINI EVENING
# Avg Speed: 3.818 m/min
# Total Time: 3515.867 mins
# Total Dist: 13424.732 ms
# ------------------------------
# Route 7W GREY ALT
# Avg Speed: 346.366 m/min
# Total Time: 32.000 mins
# Total Dist: 11083.704 ms
# ------------------------------
# Route TEAL
# Avg Speed: 15.057 m/min
# Total Time: 2067.000 mins
# Total Dist: 31122.726 ms
# ------------------------------
# Route ORANGE ALT
# Avg Speed: 431.523 m/min
# Total Time: 12.000 mins
# Total Dist: 5178.276 ms
# ------------------------------
# Route LAVENDER
# Avg Speed: 52.725 m/min
# Total Time: 1475.000 mins
# Total Dist: 77769.242 ms
# ------------------------------
# Route GREEN EXPRESS
# Avg Speed: 104.171 m/min
# Total Time: 681.000 mins
# Total Dist: 70940.315 ms
# ------------------------------
# Route YELLOWHOPPER
# Avg Speed: 8.789 m/min
# Total Time: 1245.000 mins
# Total Dist: 10942.591 ms
# ------------------------------
# Route SILVER LIMITED EVENING
# Avg Speed: 21.105 m/min
# Total Time: 160.000 mins
# Total Dist: 3376.827 ms
# ------------------------------
# Route LIME EVENING
# Avg Speed: 134.372 m/min
# Total Time: 186.000 mins
# Total Dist: 24993.187 ms
# ------------------------------
# Route ILLINI LIMITED SATURDAY
# Avg Speed: 9.136 m/min
# Total Time: 899.000 mins
# Total Dist: 8212.871 ms
# ------------------------------

# %% [markdown]
# #### 2. Bar chart: Average speed by route

# %%
route_speeds = []
routes = []
route_records = {}
for route in data['routes']['route_id'].unique().tolist():
    route_dist,route_time,route_speed = average_speed_by_route(route = route)
    if route_time != 0:
        route_records[route] = route_speed
        
route_list = sorted(route_records.items(), key=lambda d:d[1])    

for item in route_list:
    route_speeds.append(item[1])
    routes.append(item[0])

x = route_speeds
N = len(x)
y = range(N)
plt.figure(figsize=(12, 20))
plt.ylim(0,1)
plt.barh(y, x, color="blue", height = 0.7)
plt.yticks(y, routes, rotation='horizontal', size = 8)
plt.xlabel('Route Speeds(m/min)', fontsize = 18)
plt.ylabel('Route', fontsize = 18)
plt.title('Average Speed By Route', fontsize = 22)
plt.show()
