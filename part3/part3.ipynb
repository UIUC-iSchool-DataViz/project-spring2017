# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib inline

# %%
df = pd.read_csv("part3_data.csv")

# %%
data
# Out:
#               names         dates   latitude   longitude categorical  \
# 0          b'Rawad'  1.453009e+09 -19.988651  -41.435565  Category01
# 1          b'Eurma'  1.471779e+09  -8.593256   27.742604  Category00
# 2         b'Taleia'  1.473613e+09 -67.463164 -109.366796  Category04
# 3          b'Niley'  1.481194e+09  -7.537010  -32.218540  Category03
# 4           b'Acey'  1.454403e+09 -17.116866    2.949914  Category05
# 5          b'Obert'  1.463099e+09  86.050560 -138.759294  Category00
# 6          b'Kadel'  1.481066e+09  53.965137 -174.545084  Category04
# 7       b'Jaiyanna'  1.461933e+09  37.910119 -135.568743  Category04
# 8         b'Haylei'  1.469303e+09 -79.231809  168.419140  Category07
# 9          b'Ayhem'  1.454702e+09  33.318067   56.065283  Category09
# 10         b'Fedel'  1.477812e+09 -18.631134   74.340457  Category01
# 11          b'Atha'  1.466150e+09 -15.882935   33.755634  Category01
# 12       b'Taylene'  1.472723e+09  69.425034 -124.728635  Category05
# ...

# %%
time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(1453008863.05))
# Out:
# '2016-01-16 23:34:23'

# %%
type(data.latitude[0])
# Out:
# numpy.float64

# %%
categorical = data.groupby("categorical").sum()
categorical
# Out:
#                     dates     latitude    longitude       quant1       quant2  \
# categorical
# Category00   1.399919e+12  4676.187204  -355.307363  1662.078823   138.736643
# Category01   1.426359e+12  -227.165277 -3031.941079  1642.015781  -101.884839
# Category02   1.502893e+12  -575.802259 -4654.765232  1818.464364  -747.449787
# Category03   1.515616e+12   876.868185  3303.153797  1782.187066  -196.852775
# Category04   1.580445e+12  -769.061774  3448.914833  1885.125833   650.783370
# Category05   1.523116e+12   685.991985  1300.956517  1804.314132   -69.747332
# Category06   1.464161e+12  2589.669053 -3705.825059  1762.032951   350.498005
# Category07   1.490562e+12   -71.912407  4930.962362  1758.186739  -262.184698
# Category08   1.401377e+12  1104.522233  1998.882370  1621.528829  1131.077930
# Category09   1.369164e+12  1973.911980 -4058.832861  1634.836818  -577.180826
#
#                    quant3
# categorical
# Category00   4.585520e+06
# Category01   4.737484e+06
# ...

# %%
plt.plot()

# %%
len(data.names.unique())
# Out:
# 9501

# %%
plt.plot(df.longitude,df.latitude,'.b',alpha=0.2)

# %%
import plotly.plotly as py
plotly.tools.set_credentials_file(username='niteeshkanungo', api_key='qGl6RQ1RJpS0IO2OK21Y')

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
#df.head()

#df['text'] = df['airport'] + '' + df['city'] + ', ' + df['state'] + '' + 'Arrivals: ' + df['cnt'].astype(str)

scl = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]]

data = [ dict(
        type = 'scattergeo',
        locationmode = 'country names',
        lon = category0['longitude'],
        lat = category0['latitude'],
        text = category0['names'],
        mode = 'markers',
        marker = dict(
            size = 8,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'fill',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale = scl,
            cmin = 0,
            colorbar=dict(
                title="Incoming flightsFebruary 2011"
            )
        ))]
#color = df['cnt'],
#cmax = df['cnt'].max(),
            

layout = dict(
        title = 'Most trafficked US airports<br>(Hover for airport names)',
        colorbar = True,
        geo = dict(
        showframe = False,
        showcoastlines = True,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='d3-airports', alpha=0.2)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~niteeshkanungo/4.embed" height="525px" width="100%"></iframe>

# %%
uniq_categories = df.categorical.unique()
for i in df.categorical.unique():
    i = df.loc[df['categorical'] == i]

# %%
category00
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-5c77ac0c5207> in <module>()
# ----> 1 category00
#
# NameError: name 'category00' is not defined

# %%
df
# Out:
#               names         dates   latitude   longitude categorical  \
# 0          b'Rawad'  1.453009e+09 -19.988651  -41.435565  Category01
# 1          b'Eurma'  1.471779e+09  -8.593256   27.742604  Category00
# 2         b'Taleia'  1.473613e+09 -67.463164 -109.366796  Category04
# 3          b'Niley'  1.481194e+09  -7.537010  -32.218540  Category03
# 4           b'Acey'  1.454403e+09 -17.116866    2.949914  Category05
# 5          b'Obert'  1.463099e+09  86.050560 -138.759294  Category00
# 6          b'Kadel'  1.481066e+09  53.965137 -174.545084  Category04
# 7       b'Jaiyanna'  1.461933e+09  37.910119 -135.568743  Category04
# 8         b'Haylei'  1.469303e+09 -79.231809  168.419140  Category07
# 9          b'Ayhem'  1.454702e+09  33.318067   56.065283  Category09
# 10         b'Fedel'  1.477812e+09 -18.631134   74.340457  Category01
# 11          b'Atha'  1.466150e+09 -15.882935   33.755634  Category01
# 12       b'Taylene'  1.472723e+09  69.425034 -124.728635  Category05
# ...
